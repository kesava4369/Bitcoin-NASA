# %% [markdown]
# <a href="https://colab.research.google.com/github/kesava4369/Bitcoin-NASA/blob/main/Bit_coin_%26NASA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

response = requests.get('https://api.coindesk.com/v1/bpi/currentprice.json')
data = response.json()
print(data)
# Out:
# {'time': {'updated': 'Mar 8, 2023 10:49:00 UTC', 'updatedISO': '2023-03-08T10:49:00+00:00', 'updateduk': 'Mar 8, 2023 at 10:49 GMT'}, 'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org', 'chartName': 'Bitcoin', 'bpi': {'USD': {'code': 'USD', 'symbol': '&#36;', 'rate': '22,102.2593', 'description': 'United States Dollar', 'rate_float': 22102.2593}, 'GBP': {'code': 'GBP', 'symbol': '&pound;', 'rate': '18,468.4711', 'description': 'British Pound Sterling', 'rate_float': 18468.4711}, 'EUR': {'code': 'EUR', 'symbol': '&euro;', 'rate': '21,530.8275', 'description': 'Euro', 'rate_float': 21530.8275}}}

# %%
print("time:"+ str(data['time']['updated']))
# Out:
# time:Mar 8, 2023 10:49:00 UTC

# %%
print("price 1 BTC:"+str(data['bpi']['USD']['rate_float']))
# Out:
# price 1 BTC:22102.2593

# %%
print("price 1 BTC:"+str(data['bpi']['GBP']['rate_float']))
# Out:
# price 1 BTC:18468.4711

# %%
# https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?sol=1000&api_key=DEMO_KEY

import requests
api_key = "DEMO_KEY"
api_url = "https://api.nasa.gov"

params = {'sol':"1000",'api_key':api_key}

header = {'Accept':'application/json'}

response = requests.get(api_url + "/mars-photos/api/v1/rovers/curiosity/photos/",headers = header,params = params)
print(response.status_code)
# Out:
# 200

# %%
data = response.json()
photos_data = data.get('photos')
for photo_data in photos_data:
  print(photo_data['camera']['full_name'])

# %%
from skimage import io
photo_data = response.json()
photo_data = data.get('photos')
for photo_data in photos_data[0:1]:
  img_url = photo_data['img_src']
  img = io.imread(img_url)
  io.imshow(img)
  print(photo_data['camera']['id'])
# Out:
# 20
